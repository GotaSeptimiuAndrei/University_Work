# %%
t = var('t')
x = function('x')(t)
desolve(diff(x, t) + x == 2/sqrt(pi) * e ^ (-t^2 - t), x)
integral(sin(t), t)
# Out:
# -cos(t)

# %%
t = var('t')
x = function('x')(t)
sol = desolve(diff(x, t, 2) + 3 * diff(x, t) + x ==1 , x)
sol
limit(sol, t = infinity)
# Out:
# 1

# %%
t = var('t')
x = function('x')(t)
sol = desolve(diff(x, t, 2) + 4*x == 1, x, ics=[0, 5/4, 0])
sol.subs(t = pi)
# Out:
# 5/4

# %%
t = var('t')
x = function('x')(t)
sol = desolve(diff(x, t) == 3 * x + t^3, x)
sol.subs(_C = 0)
# Out:
# -1/3*t^3 - 1/3*t^2 - 2/9*t - 2/27

# %%
f = piecewise([((0, pi), t), ((pi, infinity), pi*e^(pi - t))])
plot(f, 0, 5)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
t = var('t')
x = function('x')(t)
desolve(diff(x, t, 2) + diff(x, t, 1) == t, x, ics=[0, 1])
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/sage/interfaces/interface.py in __init__(self, parent, value, is_name, name)
#     717             try:
# --> 718                 self._name = parent._create(value, name=name)
#     719             except (TypeError, RuntimeError, ValueError) as x:
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/sage/interfaces/maxima_lib.py in _create(self, value, name)
#     603             else:
# --> 604                 self.set(name, value)
#     605         except RuntimeError as error:
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/sage/interfaces/maxima_lib.py in set(self, var, value)
#     511         cmd = '%s : %s$'%(var, value.rstrip(';'))
# --> 512         self.eval(cmd)
#     513
#
# ...

# %%
f = piecewise([((0, pi), sol1), ((pi, infinity), sol2)])
plot(f, 0, 10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-bd82afc10aea> in <module>
# ----> 1 f = piecewise([((Integer(0), pi), sol1), ((pi, infinity), sol2)])
#       2 plot(f, Integer(0), Integer(10))
#
# NameError: name 'sol1' is not defined

# %%
t = var('t')
w = var('w')
x = function('x')(t)
solw = desolve(diff(x, t, 2) + x == cos(t), x, ics=[0, 0, 0], ivar = t)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-0a024cab734d> in <module>
#       3 x = function('x')(t)
#       4 solw = desolve(diff(x, t, Integer(2)) + x == cos(t), x, ics=[Integer(0), Integer(0), Integer(0)], ivar = t)
# ----> 5 limit(solw, w = Integer(1)) - sol1
#
# NameError: name 'sol1' is not defined

# %%
t = var('t')
w = var('w')
x = function('x')(t)
solw = desolve(diff(x, t, 2) + 4*x == e^(w*t), x, ics=[0, 0, 0], ivar = t)
solw.factor()
# Out:
# -1/2*(w*sin(2*t) + 2*cos(2*t) - 2*e^(t*w))/(w^2 + 4)

# %%
#ex 10
t = var('t')
x = function('x')(t)
sol1 = desolve(diff(x, t, 2) + x == t, x, ics = [0, 5, 0])
sol2 = desolve(diff(x, t, 2) + x == pi - t, x, ics = [pi/2, sol1(pi / 2), diff(sol1, t).subs(t = pi/2)])
sol3 = desolve(diff(x, t, 2) + x == 0, x, ics=[pi, sol2(pi), diff(sol2, t).subs(t = pi)])
f = piecewise([((0, pi/2), sol1), ((pi/2, pi), sol2), ((pi, infinity), sol3)])
plot(f, 0, 10)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
#ex 11
t = var('t')
x = function('x')(t)
y = function('y')(t)

sol = desolve_system([diff(x, t) == 2 * x, diff(y, t) == 3*y], [x, y], ics = [0, 1, 1])
sol
# Out:
# [x(t) == e^(2*t), y(t) == e^(3*t)]

# %%
t = var('t')
x = function('x')(t)
y = function('y')(t)
sol = desolve_system([diff(x, t) == -x + 3*y, diff(y, t) == 3*x - y], [x, y], ics = [0, 1, 1])
sol
