# %%
1/2
# Out:
# 1/2

# %%
1./2
# Out:
# 0.500000000000000

# %%
x=var('x')
eq1=x^2+x+1==0
solve(eq1,x)
# Out:
# [x == -1/2*I*sqrt(3) - 1/2, x == 1/2*I*sqrt(3) - 1/2]

# %%
trig.simplify(sin(x)^2 + cos(x)^2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-aa9c4c022115> in <module>
# ----> 1 trig.simplify(sin(x)**Integer(2) + cos(x)**Integer(2))
#
# NameError: name 'trig' is not defined

# %%
trig_simplify(sin(x)^2 + cos(x)^2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-154cec1cdd8e> in <module>
# ----> 1 trig_simplify(sin(x)**Integer(2) + cos(x)**Integer(2))
#
# NameError: name 'trig_simplify' is not defined

# %%
trig-simplify(sin(x)^2 + cos(x)^2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-31f3189614b7> in <module>
# ----> 1 trig-simplify(sin(x)**Integer(2) + cos(x)**Integer(2))
#
# NameError: name 'trig' is not defined

# %%
p = sin(x)^2 + cos(x)^2
p.trig-simplify()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-f4767878a4dc> in <module>
#       1 p = sin(x)**Integer(2) + cos(x)**Integer(2)
# ----> 2 p.trig-simplify()
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/sage/structure/element.pyx in sage.structure.element.Element.__getattr__ (build/cythonized/sage/structure/element.c:4709)()
#     491             AttributeError: 'LeftZeroSemigroup_with_category.element_class' object has no attribute 'blah_blah'
#     492         """
# --> 493         return self.getattr_from_category(name)
#     494
#     495     cdef getattr_from_category(self, name):
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/sage/structure/element.pyx in sage.structure.element.Element.getattr_from_category (build/cythonized/sage/structure/element.c:4821)()
#     504         else:
#     505             cls = P._abstract_element_class
# ...

# %%
p = sin(x)^2 + cos(x)^2
p.trig_simplify()
# Out:
# 1

# %%
f = exp(x)+ln(x)
f.subs(x=1)
# Out:
# e

# %%
eq = x^2 - 4x + 3 == 0
solve(eq, x)
# Out:
#   File "<ipython-input-10-284f68636484>", line 1
#     eq = x**Integer(2) - 4x + Integer(3) == Integer(0)
#                           ^
# SyntaxError: invalid syntax

# %%
eq = x^2 - 4*x + 3 == 0
solve(eq, x)
# Out:
# [x == 3, x == 1]

# %%
find_root(x^5-3*x^3-1, -2, 2)
# Out:
# 1.7823087800458832

# %%
var('x', 'y')
syst = [4*x + 3*y == 10, 3*x - y == 1]
solve(syst, x, y)
# Out:
# [[x == 1, y == 2]]

# %%
g = exp(x) - sin(x)
integral_numerical(g, -1, 1)
# Out:
# (2.3504023872876028, 2.609470847500631e-14)

# %%
limit(sin(x)/x, x = 0)
# Out:
# 1

# %%
plot(sin(x), 0,2*pi)
# Out:
# Matplotlib is building the font cache; this may take a moment.
# Graphics object consisting of 1 graphics primitive

# %%
var('t')
parametric_plot((2-t^2, t - t^3), (t, -2, 2), ymax = 2, ymin = -2)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
var('t')
parametric_plot((2-t^2, t - t^3), (t, 0, pi), ymax = 2, ymin = -2)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
var('t')
parametric_plot((cos(t), sin(t)), (t, 0, pi), ymax = 2, ymin = -2)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
implicit_plot((x^2 - 2xy - y^2 == 1), (x, -5, 5), (y, -5, 5))
# Out:
#   File "<ipython-input-21-423261063bc1>", line 1
#     implicit_plot((x**Integer(2) - 2xy - y**Integer(2) == Integer(1)), (x, -Integer(5), Integer(5)), (y, -Integer(5), Integer(5)))
#                                      ^
# SyntaxError: invalid syntax

# %%
implicit_plot(x^2 - 2xy - y^2 == 1), (x, -5, 5), (y, -5, 5)
# Out:
#   File "<ipython-input-22-67e72ce3299b>", line 1
#     implicit_plot(x**Integer(2) - 2xy - y**Integer(2) == Integer(1)), (x, -Integer(5), Integer(5)), (y, -Integer(5), Integer(5))
#                                     ^
# SyntaxError: invalid syntax

# %%
implicit_plot((x^2 - 2*x*y - y^2 == 1), (x, -5, 5), (y, -5, 5))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
plot3d(x^2 + y^2, (x, -2, 2), (y, -2, 2))
# Out:
# Graphics3d Object

# %%
t = var('t')
y = function('y')(t)
eq = diff(y, t) == (1 + y)^2
sol = desolve(eq, y, ics = [0, 1])
sol
# Out:
# -1/(y(t) + 1) == t - 1/2

# %%
v1 = vector([1, 1/2])
v2 = vector([0, 0.6])
A = matrix([v1, v2])
A = A * A
A
# Out:
# [ 1.00000000000000 0.800000000000000]
# [0.000000000000000 0.360000000000000]

# %%
t = var('t')
x = function('x')(t)
eq = diff(x, t, 2) + x == t^3
sol=desolve(eq, x, ics = [0, 0 , 4])
plot(sol, -100, 100)
# Out:
# Graphics object consisting of 1 graphics primitive
